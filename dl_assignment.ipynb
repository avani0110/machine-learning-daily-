# %%
import pandas as pd
import matplotlib.pyplot as plt

# load dataset
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")

# prepare data
X_train = train.drop("label", axis=1).values

# ----------------------------
# PLOT SAMPLE IMAGE
# ----------------------------
plt.imshow(X_train[0].reshape(28,28), cmap='gray')
plt.axis('off')
plt.savefig("sample_image.png")
plt.show()

# %% [markdown]
# # mlp

# %% [markdown]
# ## using only 10 epochs to understand actually what happenning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# load dataset
data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")

# split X and y
X = data.drop("label", axis=1)
y = data["label"]

# normalize
X = X / 255.0

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# build MLP
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=10, batch_size=32)

# evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8158 - loss: 0.5193
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8603 - loss: 0.3810
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8745 - loss: 0.3420
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8799 - loss: 0.3231
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8876 - loss: 0.3036
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8928 - loss: 0.2874
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8986 - loss: 0.2736
# Epoch 8/10
# ...

# %%
train_acc = model.evaluate(X_train, y_train)[1]
test_acc = model.evaluate(X_test, y_test)[1]

print("Train Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
# Out:
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9368 - loss: 0.1667
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8912 - loss: 0.3539
# Train Accuracy: 0.9367916584014893
# Test Accuracy: 0.8911666870117188

# %% [markdown]
# in this i have done normalizing data so training is done fast and by using only 10 epochs accuracy is good for both trainning and testing data so overrfitting will not happen

# %% [markdown]
# ## this is for testing what happens if epochs are more like 20

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# load dataset
data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")

# split X and y
X = data.drop("label", axis=1)
y = data["label"]

# normalize
X = X / 255.0

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# build MLP
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=20, batch_size=32)

# evaluate
loss, acc = model.evaluate(X_test, y_test)
print("Accuracy:", acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8194 - loss: 0.5133
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8606 - loss: 0.3835
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8738 - loss: 0.3437
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8834 - loss: 0.3199
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8878 - loss: 0.3032
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8936 - loss: 0.2879
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8994 - loss: 0.2744
# Epoch 8/20
# ...

# %%
train_acc = model.evaluate(X_train, y_train)[1]
test_acc = model.evaluate(X_test, y_test)[1]

print("Train Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
# Out:
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9368 - loss: 0.1667
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8912 - loss: 0.3539
# Train Accuracy: 0.9367916584014893
# Test Accuracy: 0.8911666870117188

# %%
history = model.fit(X_train, y_train,
                    epochs=5,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/5
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9377 - loss: 0.1645 - val_accuracy: 0.9256 - val_loss: 0.1988
# Epoch 2/5
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9384 - loss: 0.1622 - val_accuracy: 0.9249 - val_loss: 0.1925
# Epoch 3/5
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9397 - loss: 0.1576 - val_accuracy: 0.9284 - val_loss: 0.1870
# Epoch 4/5
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9423 - loss: 0.1486 - val_accuracy: 0.9274 - val_loss: 0.1931
# Epoch 5/5
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9440 - loss: 0.1454 - val_accuracy: 0.9242 - val_loss: 0.2112

# %%
import matplotlib.pyplot as plt

# accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy")
plt.legend(['train', 'val'])
plt.show()

# loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss")
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# in this we can observe that there is overfitting happened at epoch 20 also.

# %% [markdown]
# # Learning Rate & Optimizers

# %% [markdown]
# ## learning rate

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop

# try different optimizers
optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9465 - loss: 0.1394 - val_accuracy: 0.9261 - val_loss: 0.2067
# Epoch 2/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9484 - loss: 0.1348 - val_accuracy: 0.9143 - val_loss: 0.2490
# Epoch 3/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9491 - loss: 0.1332 - val_accuracy: 0.9270 - val_loss: 0.2062
# Epoch 4/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9526 - loss: 0.1250 - val_accuracy: 0.9260 - val_loss: 0.2125
# Epoch 5/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.9504 - loss: 0.1264 - val_accuracy: 0.9178 - val_loss: 0.2284
# Epoch 6/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9528 - loss: 0.1225 - val_accuracy: 0.9140 - val_loss: 0.2481
# Epoch 7/10
# 1200/1200 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9549 - loss: 0.1161 - val_accuracy: 0.9186 - val_loss: 0.2329
# Epoch 8/10
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# load data
data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")

X = data.drop("label", axis=1) / 255.0
y = data["label"]

# split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# learning rates to test
learning_rates = [0.00001, 0.0001, 0.001, 0.01, 0.1]

train_acc_list = []
val_acc_list = []
loss_list = []

# loop for each learning rate
for lr in learning_rates:
    print("\nTraining with LR =", lr)

    # build model (fresh every time)
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(784,)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    # compile
    model.compile(optimizer=Adam(learning_rate=lr),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # train
    history = model.fit(X_train, y_train,
                        epochs=5,
                        batch_size=32,
                        validation_split=0.2,
                        verbose=0)

    # store results
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    loss = history.history['loss'][-1]

    train_acc_list.append(train_acc)
    val_acc_list.append(val_acc)
    loss_list.append(loss)

    print(f"Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}, Loss: {loss:.4f}")

# plot results
plt.plot(learning_rates, val_acc_list, marker='o')
plt.xlabel("Learning Rate")
plt.ylabel("Validation Accuracy")
plt.title("Learning Rate vs Accuracy")
plt.show()
# Out:
# Training with LR = 1e-05
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Acc: 0.7968, Val Acc: 0.7976, Loss: 0.6358
#
# Training with LR = 0.0001
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Train Acc: 0.8610, Val Acc: 0.8593, Loss: 0.3950
#
# Training with LR = 0.001
# ...

# %% [markdown]
# in this we can check that for small learning rate accuracy is low low for normal learning rate like 0.001 it is great but for 0.01 also accuracy is slow

# %% [markdown]
# ## with all optimization techniques

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta

# load data
data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")

X = data.drop("label", axis=1) / 255.0
y = data["label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# optimizers list
optimizers = {
    "SGD": SGD(learning_rate=0.01),
    "SGD_Momentum": SGD(learning_rate=0.01, momentum=0.9),
    "Nesterov": SGD(learning_rate=0.01, momentum=0.9, nesterov=True),
    "Adagrad": Adagrad(learning_rate=0.01),
    "RMSProp": RMSprop(learning_rate=0.001),
    "Adadelta": Adadelta(),
    "Adam": Adam(learning_rate=0.001)
}

# results
results = {}

for name, opt in optimizers.items():
    print("\nTraining with", name)

    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(784,)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(X_train, y_train,
                        epochs=5,
                        batch_size=32,
                        validation_split=0.2,
                        verbose=0)

    val_acc = history.history['val_accuracy'][-1]
    results[name] = val_acc

    print(f"{name} Validation Accuracy: {val_acc:.4f}")

print("\nFinal Results:", results)
# Out:
# Training with SGD
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# SGD Validation Accuracy: 0.8176
#
# Training with SGD_Momentum
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# SGD_Momentum Validation Accuracy: 0.8610
#
# Training with Nesterov
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# load train data
train_data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
X_train = train_data.drop("label", axis=1) / 255.0
y_train = train_data["label"]

# load test data
test_data = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")
X_test = test_data.drop("label", axis=1) / 255.0
y_test = test_data["label"]

# function to build model
def build_model(optimizer):
    model = Sequential()
    model.add(Dense(128, activation='relu', input_shape=(784,)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Train with Adam
adam_model = build_model(Adam(learning_rate=0.001))
adam_history = adam_model.fit(X_train, y_train,
                              epochs=10,
                              batch_size=32,
                              validation_split=0.2,
                              verbose=0)
adam_loss, adam_acc = adam_model.evaluate(X_test, y_test, verbose=0)

# Train with SGD
sgd_model = build_model(SGD(learning_rate=0.01))
sgd_history = sgd_model.fit(X_train, y_train,
                            epochs=10,
                            batch_size=32,
                            validation_split=0.2,
                            verbose=0)
sgd_loss, sgd_acc = sgd_model.evaluate(X_test, y_test, verbose=0)

# Compare accuracies
labels = ['Adam (Train)', 'Adam (Val)', 'Adam (Test)',
          'SGD (Train)', 'SGD (Val)', 'SGD (Test)']
values = [adam_history.history['accuracy'][-1],
          adam_history.history['val_accuracy'][-1],
          adam_acc,
          sgd_history.history['accuracy'][-1],
          sgd_history.history['val_accuracy'][-1],
          sgd_acc]

plt.figure(figsize=(8,6))
bars = plt.bar(labels, values, color=['blue','orange','green','blue','orange','green'])

# Add values on top
for bar, val in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height()+0.005,
             f"{val:.4f}", ha='center', va='bottom')

plt.title("Comparison of Adam vs SGD Accuracies")
plt.ylabel("Accuracy")
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## using test dataset

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# load train data
train_data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
X_train = train_data.drop("label", axis=1) / 255.0
y_train = train_data["label"]

# load test data
test_data = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")
X_test = test_data.drop("label", axis=1) / 255.0
y_test = test_data["label"]

# build model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)

# evaluate on TEST data
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8181 - loss: 0.5119 - val_accuracy: 0.8418 - val_loss: 0.4371
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8598 - loss: 0.3823 - val_accuracy: 0.8504 - val_loss: 0.4297
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8738 - loss: 0.3403 - val_accuracy: 0.8716 - val_loss: 0.3635
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8822 - loss: 0.3182 - val_accuracy: 0.8738 - val_loss: 0.3546
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt

# Training history already stored in 'history'
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Plot training vs validation accuracy
plt.figure(figsize=(8,5))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Print test accuracy for comparison
print("Final Training Accuracy:", train_acc[-1])
print("Final Validation Accuracy:", val_acc[-1])
print("Test Accuracy:", test_acc)
# Out:
# Final Training Accuracy: 0.9079375267028809
# Final Validation Accuracy: 0.887583315372467
# Test Accuracy: 0.8877999782562256

# %% [markdown]
# in this model is learning well with 10 epochs because u can see in result that the train accuracy is 91 and val accuracy is 88 and test accuracy is 88 means model learned well and no overfitting also

# %% [markdown]
# ## high epoch to see is there any diff in train and test accuracy

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# load train data
train_data = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
X_train = train_data.drop("label", axis=1) / 255.0
y_train = train_data["label"]

# load test data
test_data = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")
X_test = test_data.drop("label", axis=1) / 255.0
y_test = test_data["label"]

# build model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
history = model.fit(X_train, y_train,
                    epochs=30,
                    batch_size=32,
                    validation_split=0.2)

# evaluate on TEST data
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8147 - loss: 0.5185 - val_accuracy: 0.8573 - val_loss: 0.4010
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8606 - loss: 0.3842 - val_accuracy: 0.8661 - val_loss: 0.3792
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8740 - loss: 0.3441 - val_accuracy: 0.8726 - val_loss: 0.3543
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8832 - loss: 0.3191 - val_accuracy: 0.8802 - val_loss: 0.3306
# Epoch 5/30
# ...

# %% [markdown]
# we can see in this that the train accuracy incresed from 91 to 95 and test accuracy is 89 so some overfitting is happend means model can learn better from this data but cant perform well on new data so correct epoch is always best

# %% [markdown]
# # Regularization

# %% [markdown]
# ## L2 regularization

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2

# load data
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1) / 255.0
y_test = test["label"]

# model with L2
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,), kernel_regularizer=l2(0.001)))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_split=0.2)

model.evaluate(X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8142 - loss: 0.7063 - val_accuracy: 0.8389 - val_loss: 0.6026
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8457 - loss: 0.5489 - val_accuracy: 0.8432 - val_loss: 0.5410
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8538 - loss: 0.5043 - val_accuracy: 0.8539 - val_loss: 0.5016
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8586 - loss: 0.4789 - val_accuracy: 0.8443 - val_loss: 0.5238
# Epoch 5/10
# ...

# %% [markdown]
# from this we can see that the models train accuracy is 87 and test also 87  means model is learning well and there is no overfitting on data means l2 handling weights on data

# %% [markdown]
# ## Dropout

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=10, validation_split=0.2)
model.evaluate(X_test, y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6955 - loss: 0.8364 - val_accuracy: 0.8201 - val_loss: 0.4974
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7893 - loss: 0.5931 - val_accuracy: 0.8421 - val_loss: 0.4369
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8067 - loss: 0.5467 - val_accuracy: 0.8468 - val_loss: 0.4199
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8142 - loss: 0.5223 - val_accuracy: 0.8450 - val_loss: 0.4182
# Epoch 5/10
# ...

# %% [markdown]
# in this we are done dropout of 50% data so data is learning on all data with turn off of some neaurons so finally we are getting train accuracy of 83 and test accuracy of 85 means there is no overfitting of data

# %% [markdown]
# ## Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

early = EarlyStopping(monitor='val_loss', patience=2)

model.fit(X_train, y_train,
          epochs=30,
          validation_split=0.2,
          callbacks=[early])
# Out:
# Epoch 1/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8444 - loss: 0.4373 - val_accuracy: 0.8617 - val_loss: 0.3686
# Epoch 2/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8453 - loss: 0.4339 - val_accuracy: 0.8582 - val_loss: 0.3777
# Epoch 3/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8453 - loss: 0.4311 - val_accuracy: 0.8634 - val_loss: 0.3673
# Epoch 4/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8503 - loss: 0.4228 - val_accuracy: 0.8696 - val_loss: 0.3561
# Epoch 5/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8482 - loss: 0.4197 - val_accuracy: 0.8733 - val_loss: 0.3559
# Epoch 6/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8486 - loss: 0.4170 - val_accuracy: 0.8675 - val_loss: 0.3691
# Epoch 7/30
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8502 - loss: 0.4150 - val_accuracy: 0.8653 - val_loss: 0.3731

# %% [markdown]
# in this we taken that monitor as val_acc and patience as 2 so if val_acc is not incresing after 2 epochs the model will stop training the data so in this the model stopped learning in eopch 7 because  moel val_acc is same in epoch 6 and 7

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    horizontal_flip=True
)

# reshape for image format
X_train_img = X_train.values.reshape(-1,28,28,1)

datagen.fit(X_train_img)

model.fit(datagen.flow(X_train_img, y_train, batch_size=32),
          epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.7251 - loss: 0.7434
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.7437 - loss: 0.6968
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.7585 - loss: 0.6690
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 14ms/step - accuracy: 0.7649 - loss: 0.6508
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.7665 - loss: 0.6421
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 35s 19ms/step - accuracy: 0.7739 - loss: 0.6331
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.7763 - loss: 0.6248
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.7785 - loss: 0.6170
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7780 - loss: 0.6142
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.7802 - loss: 0.6086

# %% [markdown]
# ## Adding Noise

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

noise = np.random.normal(0, 0.1, X_train.shape)
X_train_noisy = X_train + noise

# Re-define the model to accept the 2D noisy input for this section
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,))) # Expects 2D flattened input
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_noisy, y_train, epochs=10, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8107 - loss: 0.5303 - val_accuracy: 0.8385 - val_loss: 0.4441
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8580 - loss: 0.3864 - val_accuracy: 0.8587 - val_loss: 0.3835
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8732 - loss: 0.3423 - val_accuracy: 0.8606 - val_loss: 0.3800
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8829 - loss: 0.3130 - val_accuracy: 0.8654 - val_loss: 0.3724
# Epoch 5/10
# ...

# %% [markdown]
# ## Ensemble Methods

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# model 1
model1 = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# model 2
model2 = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])


model1.compile(optimizer=Adam(0.001),
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

model2.compile(optimizer=Adam(0.001),
               loss='sparse_categorical_crossentropy',
               metrics=['accuracy'])

# train
model1.fit(X_train, y_train, epochs=3, batch_size=32, verbose=0)
model2.fit(X_train, y_train, epochs=3, batch_size=32, verbose=0)

# evaluate individually
acc1 = model1.evaluate(X_test, y_test, verbose=0)[1]
acc2 = model2.evaluate(X_test, y_test, verbose=0)[1]

print("Model 1 Accuracy:", acc1)
print("Model 2 Accuracy:", acc2)

# predictions
pred1 = model1.predict(X_test)
pred2 = model2.predict(X_test)

# ensemble (average)
final_pred = (pred1 + pred2) / 2

# convert to labels
final_labels = np.argmax(final_pred, axis=1)

# accuracy of ensemble
ensemble_acc = np.mean(final_labels == y_test)

print("Ensemble Accuracy:", ensemble_acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model 1 Accuracy: 0.8646000027656555
# Model 2 Accuracy: 0.8744000196456909
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Ensemble Accuracy: 0.8789

# %% [markdown]
# in this result we can see that model1 accuracy is 86 and model2 accuracy is 8744  but model1+model2 combining accuracy is 8789 means better that model1 and model2 this is ensemble learning

# %% [markdown]
# # CNN

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# load data
train = pd.read_csv("/content/sample_data/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/sample_data/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=5, validation_split=0.2)

# test
print("Test Accuracy:", model.evaluate(X_test, y_test)[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 30s 19ms/step - accuracy: 0.8489 - loss: 0.4275 - val_accuracy: 0.8782 - val_loss: 0.3446
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 19ms/step - accuracy: 0.8946 - loss: 0.2956 - val_accuracy: 0.8979 - val_loss: 0.2881
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 29s 20ms/step - accuracy: 0.9080 - loss: 0.2536 - val_accuracy: 0.8967 - val_loss: 0.2844
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 28s 19ms/step - accuracy: 0.9191 - loss: 0.2215 - val_accuracy: 0.9047 - val_loss: 0.2675
# Epoch 5/5
# ...

# %% [markdown]
# from this wee can see that the cnn given the more training and testing accuracy than mlp because mlp only learning image in the form of numbers not learning exactly image shapes but cnn finding edges shapes so it is learning about image so the training accuracy and testing accuracy is very high and very close so no overfitting in data.

# %% [markdown]
# in this no sudden jumps are also happenning and learning is happenning well and loss also smooth and for epooch 1 and epoch 5 there is so diff in output so in this better feature learning is happenning.

# %% [markdown]
# Training and validation accuracy increase steadily, indicating proper learning
# Loss decreases across epochs, showing error minimization
# Small gap between training and validation accuracy indicates no overfitting
# CNN performs better than MLP due to spatial feature extraction
# Model converges around epoch 4–5

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# load data
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=5, validation_split=0.2)

# test
print("Test Accuracy:", model.evaluate(X_test, y_test)[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8505 - loss: 0.4130 - val_accuracy: 0.8924 - val_loss: 0.3158
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9078 - loss: 0.2563 - val_accuracy: 0.9103 - val_loss: 0.2511
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9251 - loss: 0.2040 - val_accuracy: 0.9197 - val_loss: 0.2231
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9402 - loss: 0.1625 - val_accuracy: 0.9201 - val_loss: 0.2371
# Epoch 5/5
# ...

# %% [markdown]
# ## Dropout on cnn

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# load data
train = pd.read_csv("/content/sample_data/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/sample_data/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    Dropout(0.5),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=5, validation_split=0.2)

# test
print("Test Accuracy:", model.evaluate(X_test, y_test)[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 47s 31ms/step - accuracy: 0.8472 - loss: 0.4307 - val_accuracy: 0.8850 - val_loss: 0.3731
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 48s 32ms/step - accuracy: 0.8896 - loss: 0.3083 - val_accuracy: 0.8960 - val_loss: 0.3236
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 45s 30ms/step - accuracy: 0.9004 - loss: 0.2706 - val_accuracy: 0.8942 - val_loss: 0.3142
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - accuracy: 0.9101 - loss: 0.2441 - val_accuracy: 0.9047 - val_loss: 0.2774
# Epoch 5/5
# ...

# %% [markdown]
# in this i have added dropout so model does not depend on specific neuronns and in this we have been observe that model is learninng general patterns and model will do generalization not memorization  and Training accuracy decreases slightly, but validation accuracy improves so this can reduce overfitting on model.

# %% [markdown]
# # Pre trained models

# %% [markdown]
# ## flow

# %% [markdown]
# Pretrained Model → Remove last layer → Add new layer → Train

# %%
import pandas as pd
import tensorflow as tf

train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# reduce data (important)
X_train = X_train[:5000]
y_train = y_train[:5000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# resize for pretrained
X_train = tf.image.resize(X_train, (224,224))
X_train = tf.repeat(X_train, 3, axis=-1)

X_test = tf.image.resize(X_test, (224,224))
X_test = tf.repeat(X_test, 3, axis=-1)

# %% [markdown]
# ## lenet

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense

model = Sequential([
    Conv2D(6, (5,5), activation='relu', input_shape=(224,224,3)),
    AveragePooling2D((2,2)),
    Conv2D(16, (5,5), activation='relu'),
    AveragePooling2D((2,2)),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(84, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("LeNet:", model.evaluate(X_test, y_test)[1])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.7446 - loss: 0.7319
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8484 - loss: 0.4063
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8842 - loss: 0.3067
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8470 - loss: 0.4365
# LeNet: 0.847000002861023

# %% [markdown]
# in this training accuracy incresed as 74,84,88  it is very smooth learning acuuracy and loss also from 73 to 30 very smooth decrese but test accuracy is 84 so slight overfitting is there but acceptable ,so this is simple model and learn basic features.

# %% [markdown]
# ## alexnet

# %%
from tensorflow.keras.layers import MaxPooling2D, Dropout

model = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("AlexNet:", model.evaluate(X_test, y_test)[1])
# Out:
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.7232 - loss: 1.0520
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step - accuracy: 0.8304 - loss: 0.4553
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - accuracy: 0.8726 - loss: 0.3528
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.8430 - loss: 0.4126
# AlexNet: 0.8429999947547913

# %% [markdown]
# in this alexnet also train acuuracy increses slightly from 72 and 83 to 87 but loss id decresing very fastly like 1.05 to 45 and 35 and test accuracy is also same as lenet that is 84.in this i took just 3 epochs so alexnet is not fully trained and also alexnet needs more data.

# %% [markdown]
# ## zfnet

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("ZFNet:", model.evaluate(X_test, y_test)[1])
# Out:
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.7524 - loss: 0.7406
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.8576 - loss: 0.3836
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - accuracy: 0.8992 - loss: 0.2816
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8500 - loss: 0.4402
# ZFNet: 0.8500000238418579

# %% [markdown]
# in zfnet learning behaviour is as 75 and 85 and 89 like slightly incresing and loss also 74 to 28 it is good reduction but test accuracy is 0.85 so slight overfiting can happen but it is better than lent.

# %% [markdown]
# ## vggnet

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Model

base = VGG16(weights='imagenet', include_top=False,input_shape=(224,224,3))

for layer in base.layers:
    layer.trainable = False

x = Flatten()(base.output)
x = Dense(64, activation='relu')(x)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=base.input, outputs=output)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("VGG:", model.evaluate(X_test, y_test)[1])
# Out:
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 63s 271ms/step - accuracy: 0.7396 - loss: 0.7356
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 34s 219ms/step - accuracy: 0.8666 - loss: 0.3683
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 35s 224ms/step - accuracy: 0.8940 - loss: 0.2928
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - accuracy: 0.8770 - loss: 0.3378
# VGG: 0.8769999742507935

# %% [markdown]
# in vggnet train accuracy is as 73 and then 86 and 89 like slightly incresing and loss is first 73 and then 29 it is good improvement but in this we can observe that test accuracy is 87 so train accuracy and test accuracy diff is only 1.7 so it is very good generalization ,it is very model learn better features and less overfitting than zfnet.

# %% [markdown]
# ## Googlenet

# %%
from tensorflow.keras.applications import InceptionV3

base = InceptionV3(weights='imagenet', include_top=False,input_shape=(224,224,3))

for layer in base.layers:
    layer.trainable = False

x = Flatten()(base.output)
x = Dense(64, activation='relu')(x)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=base.input, outputs=output)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("GoogLeNet:", model.evaluate(X_test, y_test)[1])
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 35s 122ms/step - accuracy: 0.5680 - loss: 2.0436
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - accuracy: 0.6832 - loss: 0.9537
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 12s 74ms/step - accuracy: 0.7426 - loss: 0.7917
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.7290 - loss: 0.8744
# GoogLeNet: 0.7289999723434448

# %% [markdown]
# in this google net learning is happenning but slower than others like 56 68 and 74 but loss is improved more like 2.04 to 0.79 model is improving and test accuracy is 72 so it is very good generalization but less acccuracy, so it is not overfitting but accuracy is low.

# %% [markdown]
# ## Resnet

# %%
from tensorflow.keras.applications import ResNet50

base = ResNet50(weights='imagenet', include_top=False,input_shape=(224,224,3))

for layer in base.layers:
    layer.trainable = False

x = Flatten()(base.output)
x = Dense(64, activation='relu')(x)
output = Dense(10, activation='softmax')(x)

model = Model(inputs=base.input, outputs=output)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=3)
print("ResNet:", model.evaluate(X_test, y_test)[1])
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Epoch 1/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 34s 136ms/step - accuracy: 0.1672 - loss: 2.4044
# Epoch 2/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - accuracy: 0.3174 - loss: 1.8648
# Epoch 3/3
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.3534 - loss: 1.7436
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.3440 - loss: 1.6310
# ResNet: 0.3440000116825104

# %% [markdown]
# in resnet learning happenning as 16 and 31 and 35 it is very poor learning and loss also from 2.40 to 1.74 but still very high and test accuracy is 34 so both train and tet accuracy are same there is no overfitting but because of less accuracy there is happenning underfitting on data ,  so this resnet failed to leran.

# %% [markdown]
# why this googlenet and resnet performed poorly is reason 1 dataset is small and iam taking just 3 epochs and pretrained model trained on iamgenet but my datasset is fashion mnist so features doesnot match  so in this i have understood that big dataset always good and i have understood that lenet is slightly overfitting and zfnet modererate overfitting and vggnet is best balance and googlenet is slightly underfitting but resnet is strong underfitting.

# %% [markdown]
# Simpler models like LeNet perform well on small datasets
# VGG achieves the best performance due to balanced depth
# GoogLeNet and ResNet underperform due to insufficient data and training
# Very deep models require large datasets and longer training
# Model complexity must match dataset size

# %% [markdown]
# # CNN Visualization

# %% [markdown]
# so this cnn visualization is seeing acually what model is learning

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# reduce size (fast)
X_train = X_train[:5000]
y_train = y_train[:5000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# ----------------------------
# 2. BUILD CNN (Functional API)
# ----------------------------
inputs = Input(shape=(28,28,1))

x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs, outputs)

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# ----------------------------
# 3. TRAIN
# ----------------------------
model.fit(X_train, y_train, epochs=3, validation_split=0.2)

# ----------------------------
# 4. VISUALIZATION MODEL
# ----------------------------
# take first conv layer
conv_layer = model.layers[1]

vis_model = Model(inputs=model.input, outputs=conv_layer.output)

# ----------------------------
# 5. GET FEATURE MAPS
# ----------------------------
img = X_test[0:1]
feature_maps = vis_model.predict(img)

# ----------------------------
# 6. PLOT
# ----------------------------
plt.figure(figsize=(8,5))

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(feature_maps[0,:,:,i], cmap='gray')
    plt.title(f"Filter {i}")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6998 - loss: 0.8570 - val_accuracy: 0.7840 - val_loss: 0.5767
# Epoch 2/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8152 - loss: 0.4945 - val_accuracy: 0.8210 - val_loss: 0.4858
# Epoch 3/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8615 - loss: 0.3854 - val_accuracy: 0.8200 - val_loss: 0.4919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step

# %% [markdown]
# The convolutional layer extracts different features using multiple filters
# Some filters highlight edges while others capture shapes and textures
# Bright regions in feature maps indicate strong activation
# Dark regions indicate less important areas
# Early layers detect low-level features like edges and outlines

# %% [markdown]
# ## with 10 epochs and changing more layers and added dropout

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input,Dropout

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# reduce size (fast)
X_train = X_train[:5000]
y_train = y_train[:5000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# ----------------------------
# 2. BUILD CNN (Functional API)
# ----------------------------
inputs = Input(shape=(28,28,1))

x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)

x = Conv2D(64, (3,3), activation='relu')(x)   # NEW
x = MaxPooling2D((2,2))(x)
x = Dropout(0.3)(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs, outputs)

# compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# ----------------------------
# 3. TRAIN
# ----------------------------
model.fit(X_train, y_train, epochs=10, validation_split=0.2)

# ----------------------------
# 4. VISUALIZATION MODEL
# ----------------------------
# take first conv layer
conv_layer = model.layers[3]

vis_model = Model(inputs=model.input, outputs=conv_layer.output)

# ----------------------------
# 5. GET FEATURE MAPS
# ----------------------------
img = X_test[0:1]
feature_maps = vis_model.predict(img)

# ----------------------------
# 6. PLOT
# ----------------------------
plt.figure(figsize=(8,5))

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(feature_maps[0,:,:,i], cmap='gray')
    plt.title(f"Filter {i}")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.6077 - loss: 1.0789 - val_accuracy: 0.7690 - val_loss: 0.6233
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7673 - loss: 0.6143 - val_accuracy: 0.7770 - val_loss: 0.5760
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8060 - loss: 0.5197 - val_accuracy: 0.8110 - val_loss: 0.5014
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8328 - loss: 0.4614 - val_accuracy: 0.8150 - val_loss: 0.4799
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8338 - loss: 0.4401 - val_accuracy: 0.8210 - val_loss: 0.4405
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8478 - loss: 0.4043 - val_accuracy: 0.8370 - val_loss: 0.4281
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8615 - loss: 0.3877 - val_accuracy: 0.8270 - val_loss: 0.4304
# Epoch 8/10
# ...

# %% [markdown]
# in this i have changed the epochs from 3 to 10 and added more conv layers and also added the dropout by doing this all the models train accuracy improved from 86 to 88 and validation accuracy also 83 but validation loss is incresing and decresing .

# %% [markdown]
# # Guided backpropagation

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# small dataset
X_train = X_train[:5000]
y_train = y_train[:5000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# ----------------------------
# 2. BUILD MODEL
# ----------------------------
inputs = Input(shape=(28,28,1))

x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs, outputs)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=3, validation_split=0.2)

# ----------------------------
# 3. GUIDED BACKPROP
# ----------------------------

# pick one image
img = X_test[0:1]
img_tensor = tf.convert_to_tensor(img)

with tf.GradientTape() as tape:
    tape.watch(img_tensor)
    preds = model(img_tensor)

    # get predicted class
    class_idx = tf.argmax(preds[0])
    loss = preds[:, class_idx]

# compute gradients
grads = tape.gradient(loss, img_tensor)

# guided backprop: keep only positive gradients
guided_grads = tf.maximum(grads, 0)

# convert to numpy
guided_grads = guided_grads.numpy()[0]

# ----------------------------
# 4. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,3))

# original image
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(img[0].reshape(28,28), cmap='gray')
plt.axis('off')

# guided backprop image
plt.subplot(1,2,2)
plt.title("Guided Backprop")
plt.imshow(guided_grads.reshape(28,28), cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Epoch 1/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6975 - loss: 0.8798 - val_accuracy: 0.7870 - val_loss: 0.5864
# Epoch 2/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8150 - loss: 0.5092 - val_accuracy: 0.7960 - val_loss: 0.5781
# Epoch 3/3
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8403 - loss: 0.4353 - val_accuracy: 0.8250 - val_loss: 0.5001

# %% [markdown]
# Guided backpropagation highlights important pixels contributing to prediction
# Bright regions correspond to edges and object boundaries
# Background regions are mostly ignored
# The model focuses on shape and structure of the object
# Only a subset of pixels influence the final prediction

# %% [markdown]
# ## using more epochs

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_train = train["label"]

X_test = test.drop("label", axis=1).values.reshape(-1,28,28,1) / 255.0
y_test = test["label"]

# small dataset
X_train = X_train[:5000]
y_train = y_train[:5000]
X_test = X_test[:1000]
y_test = y_test[:1000]

# ----------------------------
# 2. BUILD MODEL
# ----------------------------
inputs = Input(shape=(28,28,1))

x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
outputs = Dense(10, activation='softmax')(x)

model = Model(inputs, outputs)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
model.fit(X_train, y_train, epochs=10, validation_split=0.2)

# ----------------------------
# 3. GUIDED BACKPROP
# ----------------------------

# pick one image
img = X_test[0:1]
img_tensor = tf.convert_to_tensor(img)

with tf.GradientTape() as tape:
    tape.watch(img_tensor)
    preds = model(img_tensor)

    # get predicted class
    class_idx = tf.argmax(preds[0])
    loss = preds[:, class_idx]

# compute gradients
grads = tape.gradient(loss, img_tensor)

# guided backprop: keep only positive gradients
guided_grads = tf.maximum(grads, 0)

# convert to numpy
guided_grads = guided_grads.numpy()[0]

# ----------------------------
# 4. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,3))

# original image
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(img[0].reshape(28,28), cmap='gray')
plt.axis('off')

# guided backprop image
plt.subplot(1,2,2)
plt.title("Guided Backprop")
plt.imshow(guided_grads.reshape(28,28), cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7195 - loss: 0.8360 - val_accuracy: 0.7930 - val_loss: 0.5999
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8347 - loss: 0.4780 - val_accuracy: 0.7930 - val_loss: 0.5480
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8637 - loss: 0.3781 - val_accuracy: 0.8330 - val_loss: 0.4766
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8860 - loss: 0.3299 - val_accuracy: 0.8430 - val_loss: 0.4425
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 0.2841 - val_accuracy: 0.8510 - val_loss: 0.4289
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9097 - loss: 0.2471 - val_accuracy: 0.8600 - val_loss: 0.4276
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9240 - loss: 0.2244 - val_accuracy: 0.8540 - val_loss: 0.4207
# Epoch 8/10
# ...

# %% [markdown]
# with 3 epochs we can observe that the train accuracy 84 and val accuracy is 82 there is only small gap so no ovefitting but with 10 epochs training accuiacy is very nice like 95 but val accuracy is 85 so overfitting can happen on data, and loss also decresing and after some time incresing.

# %% [markdown]
# # Encoder and decoder

# %% [markdown]
# auto encoder

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values / 255.0
X_test = test.drop("label", axis=1).values / 255.0

# small dataset (fast)
X_train = X_train[:5000]
X_test = X_test[:1000]

# ----------------------------
# 2. BUILD AUTOENCODER
# ----------------------------

# input layer (784 pixels)
input_img = Input(shape=(784,))

# -------- Encoder --------
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)   # latent space

# -------- Decoder --------
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# full model
autoencoder = Model(input_img, decoded)

# ----------------------------
# 3. COMPILE
# ----------------------------
autoencoder.compile(optimizer='adam',
                    loss='mse')

# ----------------------------
# 4. TRAIN
# ----------------------------
autoencoder.fit(X_train, X_train,
                epochs=5,
                batch_size=32,
                validation_split=0.2)

# ----------------------------
# 5. PREDICT (RECONSTRUCTION)
# ----------------------------
reconstructed = autoencoder.predict(X_test)

# ----------------------------
# 6. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,4))

for i in range(5):
    # original
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # reconstructed
    plt.subplot(2,5,i+6)
    plt.imshow(reconstructed[i].reshape(28,28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0701 - val_loss: 0.0452
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0364 - val_loss: 0.0316
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0277 - val_loss: 0.0263
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - val_loss: 0.0247
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0234 - val_loss: 0.0238
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# The autoencoder successfully reconstructs input images from compressed representations
# The reconstructed images preserve overall shape but lose fine details
# Blurring occurs due to dimensionality reduction
# Training and validation loss decrease steadily, indicating proper learning
# The small gap between training and validation loss shows no overfitting

# %% [markdown]
# ## Undercomplete Autoencoder

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values / 255.0
X_test = test.drop("label", axis=1).values / 255.0

# small dataset
X_train = X_train[:5000]
X_test = X_test[:1000]

# ----------------------------
# 2. BUILD UNDERCOMPLETE AE
# ----------------------------
input_img = Input(shape=(784,))

# Encoder (strong compression)
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(16, activation='relu')(encoded)   # 🔥 small latent space

# Decoder
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Model
autoencoder = Model(input_img, decoded)

# ----------------------------
# 3. COMPILE
# ----------------------------
autoencoder.compile(optimizer='adam', loss='mse')

# ----------------------------
# 4. TRAIN
# ----------------------------
history = autoencoder.fit(X_train, X_train,
                          epochs=5,
                          batch_size=32,
                          validation_split=0.2)

# ----------------------------
# 5. RECONSTRUCTION
# ----------------------------
reconstructed = autoencoder.predict(X_test)

# ----------------------------
# 6. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,4))

for i in range(5):
    # original
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # reconstructed
    plt.subplot(2,5,i+6)
    plt.imshow(reconstructed[i].reshape(28,28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0719 - val_loss: 0.0455
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389 - val_loss: 0.0328
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0287 - val_loss: 0.0282
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0252 - val_loss: 0.0246
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - val_loss: 0.0234
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# Undercomplete autoencoder compresses input into a smaller latent space
# As latent dimension decreases, reconstruction quality reduces
# Important features like shape are preserved, but fine details are lost
# Higher compression leads to more information loss
# There is a trade-off between compression and reconstruction quality

# %% [markdown]
# ## Overcomplete Autoencoder

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values / 255.0
X_test = test.drop("label", axis=1).values / 255.0

# small dataset
X_train = X_train[:5000]
X_test = X_test[:1000]

# ----------------------------
# 2. BUILD OVERCOMPLETE AE
# ----------------------------
input_img = Input(shape=(784,))

# Encoder (EXPANSION)
encoded = Dense(512, activation='relu')(input_img)
encoded = Dense(1024, activation='relu')(encoded)   # 🔥 bigger than input

# Decoder
decoded = Dense(512, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Model
autoencoder = Model(input_img, decoded)

# ----------------------------
# 3. COMPILE
# ----------------------------
autoencoder.compile(optimizer='adam', loss='mse')

# ----------------------------
# 4. TRAIN
# ----------------------------
history = autoencoder.fit(X_train, X_train,
                          epochs=5,
                          batch_size=32,
                          validation_split=0.2)

# ----------------------------
# 5. RECONSTRUCTION
# ----------------------------
reconstructed = autoencoder.predict(X_test)

# ----------------------------
# 6. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,4))

for i in range(5):
    # original
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # reconstructed
    plt.subplot(2,5,i+6)
    plt.imshow(reconstructed[i].reshape(28,28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0477 - val_loss: 0.0274
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0245 - val_loss: 0.0220
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - val_loss: 0.0185
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0147 - val_loss: 0.0147
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %% [markdown]
# Overcomplete autoencoder has latent dimension larger than input  that we can see we taken output as 1024,
# It produces better reconstruction with less information loss
# Images appear sharper compared to undercomplete AE
# The model may memorize input instead of learning meaningful features
# Overcomplete AE requires regularization to prevent overfitting

# %% [markdown]
# ## regularized ae

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.regularizers import l2

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values / 255.0
X_test = test.drop("label", axis=1).values / 255.0

# small dataset
X_train = X_train[:5000]
X_test = X_test[:1000]

# ----------------------------
# 2. BUILD REGULARIZED AE
# ----------------------------
input_img = Input(shape=(784,))

# Encoder with regularization
encoded = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(input_img)
encoded = Dropout(0.3)(encoded)
encoded = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(encoded)

# Decoder
decoded = Dense(512, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Model
autoencoder = Model(input_img, decoded)

# ----------------------------
# 3. COMPILE
# ----------------------------
autoencoder.compile(optimizer='adam', loss='mse')

# ----------------------------
# 4. TRAIN
# ----------------------------
history = autoencoder.fit(X_train, X_train,
                          epochs=5,
                          batch_size=32,
                          validation_split=0.2)

# ----------------------------
# 5. RECONSTRUCTION
# ----------------------------
reconstructed = autoencoder.predict(X_test)

# ----------------------------
# 6. VISUALIZATION
# ----------------------------
plt.figure(figsize=(8,4))

for i in range(5):
    # original
    plt.subplot(2,5,i+1)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # reconstructed
    plt.subplot(2,5,i+6)
    plt.imshow(reconstructed[i].reshape(28,28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.2411 - val_loss: 0.0459
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0409 - val_loss: 0.0356
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0354 - val_loss: 0.0332
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0337 - val_loss: 0.0317
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0322 - val_loss: 0.0310
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step

# %% [markdown]
# in overcomplete ae the model is memorizing so for that we use this model,Regularization prevents the model from memorizing input data
# L2 regularization penalizes large weights and improves generalization
# Dropout forces the model to learn robust features
# Reconstruction becomes smoother and less overfitted
# Slight increase in loss is observed due to constraints

# %% [markdown]
# ## denoising autoencoder

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# ----------------------------
# 1. LOAD DATA
# ----------------------------
train = pd.read_csv("/content/fashion-mnist_train.csv (1).zip")
test = pd.read_csv("/content/fashion-mnist_test.csv (1).zip")

X_train = train.drop("label", axis=1).values / 255.0
X_test = test.drop("label", axis=1).values / 255.0

# small dataset
X_train = X_train[:5000]
X_test = X_test[:1000]

# ----------------------------
# 2. ADD NOISE
# ----------------------------
noise_factor = 0.3   # 🔥 change this (0.1, 0.3, 0.5)

X_train_noisy = X_train + noise_factor * np.random.normal(size=X_train.shape)
X_test_noisy = X_test + noise_factor * np.random.normal(size=X_test.shape)

# keep values between 0 and 1
X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# ----------------------------
# 3. BUILD AUTOENCODER
# ----------------------------
input_img = Input(shape=(784,))

encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)

decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)

# ----------------------------
# 4. COMPILE
# ----------------------------
autoencoder.compile(optimizer='adam', loss='mse')

# ----------------------------
# 5. TRAIN (IMPORTANT)
# ----------------------------
# input = noisy, output = clean
autoencoder.fit(X_train_noisy, X_train,
                epochs=5,
                batch_size=32,
                validation_split=0.2)

# ----------------------------
# 6. RECONSTRUCTION
# ----------------------------
reconstructed = autoencoder.predict(X_test_noisy)

# ----------------------------
# 7. VISUALIZATION
# ----------------------------
plt.figure(figsize=(10,5))

for i in range(5):
    # noisy
    plt.subplot(3,5,i+1)
    plt.imshow(X_test_noisy[i].reshape(28,28), cmap='gray')
    plt.title("Noisy")
    plt.axis('off')

    # original
    plt.subplot(3,5,i+6)
    plt.imshow(X_test[i].reshape(28,28), cmap='gray')
    plt.title("Original")
    plt.axis('off')

    # reconstructed
    plt.subplot(3,5,i+11)
    plt.imshow(reconstructed[i].reshape(28,28), cmap='gray')
    plt.title("Reconstructed")
    plt.axis('off')

plt.show()
# Out:
# Epoch 1/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0684 - val_loss: 0.0414
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0352 - val_loss: 0.0310
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0285 - val_loss: 0.0277
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0259 - val_loss: 0.0266
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0242 - val_loss: 0.0248
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# Denoising autoencoder reconstructs clean images from noisy inputs
# Model learns robust feature representations
# Moderate noise levels can be effectively removed
# High noise levels reduce reconstruction quality
# The model preserves shape but may lose fine details
